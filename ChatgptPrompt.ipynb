# %%
OPENAI_API_KEY =  'YOUR_OPENAI_API'

# %%
import os
from openai import OpenAI

# %%
import PyPDF2
import pandas as pd
import tiktoken

def count_tokens(text):
    encoding = tiktoken.get_encoding("cl100k_base")
    num_tokens = len(encoding.encode(text))
    return num_tokens

def process_pdf_files(pdf_files):
    data = []  # Create an empty list to store the data
    for pdf in pdf_files:  # Iterate over the PDF files
        with open(pdf, 'rb') as pdf_content:  # Open the PDF file
            pdf_reader = PyPDF2.PdfReader(pdf_content)  # Create a PDF reader object
            for page_num in range(len(pdf_reader.pages)):  # Iterate over all the pages
                page = pdf_reader.pages[page_num]  # Get the current page
                page_text = page.extract_text()  # Extract text from the current page
                print(page_text)
                if page_text:
                    words = page_text.split()  # Split the page text into individual words
                    page_text_join = ' '.join(words)  # Join the words back into a single string
                    page_len = len(page_text_join)
                    div_len = page_len // 2  # Divide the page length by 2
                    page_parts = [page_text_join[i * div_len:(i + 1) * div_len] for i in range(2)]
                    for i, page_part in enumerate(page_parts):  # Iterate over each part
                        data.append({
                            'file name': pdf,
                            'page number': page_num + 1,
                            'page section': i + 1,
                            'content': page_part,
                            'tokens': count_tokens(page_part)
                        })
                        print(page_part)
                else:
                    # Handle pages where no text was extracted
                    for i in range(2):
                        data.append({
                            'file name': pdf,
                            'page number': page_num + 1,
                            'page section': i + 1,
                            'content': '',
                            'tokens': 0
                        })
    return pd.DataFrame(data)

# %%
file_names = ['./Document/c4nr06660j.pdf', './Document/c4nr06660j1.pdf']
client = OpenAI(api_key = OPENAI_API_KEY, )

df = process_pdf_files(file_names)
print("Initial Data Extraction Complete")
# Out:
# Nanoscale
# COMMUNICATION
# Cite this: Nanoscale , 2015, 7, 2260
# Received 11th November 2014,
# Accepted 22nd December 2014
# DOI: 10.1039/c4nr06660j
# www.rsc.org/nanoscaleMonodisperse Sr –La2O3hybrid nano ﬁbers for
# oxidative coupling of methane to synthesize
# C2hydrocarbons †
# Jianjun Song,a,bYongnan Sun,a,cRongbin Ba,a,bShuangshuang Huang,a,b
# Yonghui Zhao,aJun Zhang,aYuhan Sun*aand Yan Zhu*a
# The synergistic e ﬀects from combinations of each component ’s
# functionality in hybrid Sr –La2O3nanoﬁbers brought about an
# improved catalytic behaviour for oxidative coupling of methane
# carried out at high temperatures, which cannot be achieved over
# the conventional Sr doped La 2O3spherical catalyst.
# Hybrid nanocatalysts with di ﬀerent components arranged in a
# controlled structure are widely used in industry since they can
# provide an entirely novel activity and selectivity for manyimportant chemical reactions viathe coupling between com-
# ponents within the hybrids.
# 1–3This class of hybrid nano-
# materials combines dissimilar materials into a singlemultifunctional material, and facilitates the electron or charge
# and energy flow between constituent hybrids.
# 4–6Diﬀerent
# functionalities from each component of hybrids can be inte-grated to bring about a synergistic e ﬀect and a new function-
# ality, so the hybrid nanocatalysts are desirable for catalytic
# reactions.
# 7,8Progress in nanomaterial synthesis has made it
# possible for developing synthetic strategies for hybrid nanoma-
# terials, such as metal oxide-metallic,6,9semiconductor-
# metallic10and semiconductor-magnetic hybrid nanomaterials.11
# However, most of these hybrid nanomaterials are used under
# mild reaction conditions and it remains unclear whether
# hybrid nanomaterials are stable when they are used as catalystsfor high temperature reactions since one component as a
# dopant is very mobile and easy to remove from the hybrids
# under high temperature conditions.
# 12In particular, direct
# conversion of CH 4to form chemicals such as oxidative
# coupling of methane (OCM) is di ﬃcult to achieve under mild
# conditions, and the activation of CH 4to a methyl radical by the
# abstraction of the H-atom with the aid of O 2and the couplingof methyl radicals to form C 2hydrocarbons (ethane/ethene)
# are carried out at a high temperature ( ∼800 °C).12–15The
# severe high temperature conditions could lead to the complete
# oxidization of methane to produce CO and CO 2, and moreover
# suppress the selectivity of C 2hydrocarbons.16,17Thanks to the
# discovery in previous investigations that La 2O3nanorods
# exhibit a low ignition temperature (450 °C) for CH 4compared
# with the corresponding nanoparticles,18it is now possible for
# precise synthesis of metal-inserted La 2O3hybrid nanofibers by
# a facile route for OCM reaction.
# In the present work, we report, for the first time, the target-
# specific synthesis of monodisperse hybrid Sr –La2O3nanofibers
# through an incipient wetness impregnation route. Sr –La2O3
# nanofibers acted as catalysts for oxidative coupling of
# methane, unprecedented in the literature, the initial ignition
# temperature of methane is about 500 °C, and the conversion
# of methane and the selectivity of C 2hydrocarbons could be up
# to∼35% and 47% at 500 °C (Fig. 1), respectively. Among the
# hybrid Sr –La2O3nanofibers, 8.6 wt% Sr –La2O3nanofibers (the
# content of Sr is 8.6 wt%) exhibited the highest methane con-version and C
# 2selectivity, in particular 20% yield of C 2hydro-
# carbons was obtained at 650 °C (Fig. 1b), which cannot be
# achieved over conventional Sr doped La 2O3spherical catalysts
# (Fig. S1 †). More ethene and ethane can be produced on the Sr –
# La2O3nanofiber compared to pure La 2O3(Fig. 1c). The com-
# plete oxidation products like CO and CO 2can be suppressed
# on Sr –La2O3nanofibers (Fig. 1d). La 2O3nanofibers modified
# with other metals such as Ba, Ca and K cannot exhibit superior
# catalysis to Sr –La2O3nanofibers in OCM reactions (Fig. S2 †).
# In addition, the hybrid Sr –La2O3nanofibers showed a good
# stability during the oxidative coupling of methane at tempera-
# tures tested, which can be inferred from the stability testunder di ﬀerent reaction conditions. From Fig. S3, †it was
# found that the conversion of CH
# 4and the yield of C 2decreased
# slightly during the 100 hour test. The improved activity andselectivity over Sr –La
# 2O3nanofibers are attributed to the syner-
# gistic e ﬀect of material properties of individual Sr and La 2O3
# optimized independently; Sr might tailor the lattice structure
# and electronic structure of La 2O3, change the oxygen species†Electronic supplementary information (ESI) available. See DOI: 10.1039/
# c4nr06660jaCAS Key Laboratory of Low-Carbon Conversion Science and Engineering, Shanghai
# Advanced Research Institute, Chinese Academy of Sciences, Shanghai 201210, China.
# E-mail: zhuy@sari.ac.cn, sunyh@sari.ac.cn
# bUniversity of Chinese Academy of Sciences, Beijing 100049, China
# cDepartment of Materials and Science and Engineering, Shanghai University,
# Shanghai, 200444, China
# 2260 |Nanoscale ,2 0 1 5 , 7, 2260 –2264 This journal is © The Royal Society of Chemistry 2015
# Published on 23 December 2014. Downloaded by Durham University Library on 6/24/2024 1:45:13 PM.
# View Article Online
# View Journal
#  | View Issue
# Nanoscale COMMUNICATION Cite this: Nanoscale , 2015, 7, 2260 Received 11th November 2014, Accepted 22nd December 2014 DOI: 10.1039/c4nr06660j www.rsc.org/nanoscaleMonodisperse Sr –La2O3hybrid nano ﬁbers for oxidative coupling of methane to synthesize C2hydrocarbons † Jianjun Song,a,bYongnan Sun,a,cRongbin Ba,a,bShuangshuang Huang,a,b Yonghui Zhao,aJun Zhang,aYuhan Sun*aand Yan Zhu*a The synergistic e ﬀects from combinations of each component ’s functionality in hybrid Sr –La2O3nanoﬁbers brought about an improved catalytic behaviour for oxidative coupling of methane carried out at high temperatures, which cannot be achieved over the conventional Sr doped La 2O3spherical catalyst. Hybrid nanocatalysts with di ﬀerent components arranged in a controlled structure are widely used in industry since they can provide an entirely novel activity and selectivity for manyimportant chemical reactions viathe coupling between com- ponents within the hybrids. 1–3This class of hybrid nano- materials combines dissimilar materials into a singlemultifunctional material, and facilitates the electron or charge and energy flow between constituent hybrids. 4–6Diﬀerent functionalities from each component of hybrids can be inte-grated to bring about a synergistic e ﬀect and a new function- ality, so the hybrid nanocatalysts are desirable for catalytic reactions. 7,8Progress in nanomaterial synthesis has made it possible for developing synthetic strategies for hybrid nanoma- terials, such as metal oxide-metallic,6,9semiconductor- metallic10and semiconductor-magnetic hybrid nanomaterials.11 However, most of these hybrid nanomaterials are used under mild reaction conditions and it remains unclear whether hybrid nanomaterials are stable when they are used as catalystsfor high temperature reactions since one component as a dopant is very mobile and easy to remove from the hybrids under high temperature conditions. 12In particular, direct conversion of CH 4to form chemicals such as oxidative coupling of methane (OCM) is di ﬃcult to achieve under mild conditions, and the activation of CH 4to a methyl radical by the abstraction of the H-atom with the aid of O 2and the couplingof methyl radicals to form C 2hydrocarbons (ethane/ethene) are carried out at a high temperature ( ∼800 °C).12–15The severe high temperature conditions could lead to the complete oxidization of methane to produce CO and CO 2, and moreover suppress the selectivity of C 2hydrocarbons.16,17Thanks to the discovery in previous investigations that La 2O3nanorods exhibit a low ignition temperature (450 °C) for CH 4compared with the
# corresponding nanoparticles,18it is now possible for precise synthesis of metal-inserted La 2O3hybrid nanofibers by a facile route for OCM reaction. In the present work, we report, for the first time, the target- specific synthesis of monodisperse hybrid Sr –La2O3nanofibers through an incipient wetness impregnation route. Sr –La2O3 nanofibers acted as catalysts for oxidative coupling of methane, unprecedented in the literature, the initial ignition temperature of methane is about 500 °C, and the conversion of methane and the selectivity of C 2hydrocarbons could be up to∼35% and 47% at 500 °C (Fig. 1), respectively. Among the hybrid Sr –La2O3nanofibers, 8.6 wt% Sr –La2O3nanofibers (the content of Sr is 8.6 wt%) exhibited the highest methane con-version and C 2selectivity, in particular 20% yield of C 2hydro- carbons was obtained at 650 °C (Fig. 1b), which cannot be achieved over conventional Sr doped La 2O3spherical catalysts (Fig. S1 †). More ethene and ethane can be produced on the Sr – La2O3nanofiber compared to pure La 2O3(Fig. 1c). The com- plete oxidation products like CO and CO 2can be suppressed on Sr –La2O3nanofibers (Fig. 1d). La 2O3nanofibers modified with other metals such as Ba, Ca and K cannot exhibit superior catalysis to Sr –La2O3nanofibers in OCM reactions (Fig. S2 †). In addition, the hybrid Sr –La2O3nanofibers showed a good stability during the oxidative coupling of methane at tempera- tures tested, which can be inferred from the stability testunder di ﬀerent reaction conditions. From Fig. S3, †it was found that the conversion of CH 4and the yield of C 2decreased slightly during the 100 hour test. The improved activity andselectivity over Sr –La 2O3nanofibers are attributed to the syner- gistic e ﬀect of material properties of individual Sr and La 2O3 optimized independently; Sr might tailor the lattice structure and electronic structure of La 2O3, change the oxygen species†Electronic supplementary information (ESI) available. See DOI: 10.1039/ c4nr06660jaCAS Key Laboratory of Low-Carbon Conversion Science and Engineering, Shanghai Advanced Research Institute, Chinese Academy of Sciences, Shanghai 201210, China. E-mail: zhuy@sari.ac.cn, sunyh@sari.ac.cn bUniversity of Chinese Academy of Sciences, Beijing 100049, China cDepartment of Materials and Science and Engineering, Shanghai University, Shanghai, 200444, China 2260 |Nanoscale ,2 0 1 5 , 7, 2260 –2264 This journal is © The Royal Society of Chemistry 2015 Published on 23 December 2014. Downloaded by Durham University Library on 6/24/2024 1:45:13 PM. View Article Online View Journal | View Issu
# and basic sites on the surface of La 2O3, and lower the reaction
# energy of CH 4on the surface of hybrid catalysts, which have
# been revealed by our studies.
# We now turn to find the reasons why the hybrid Sr –La2O3
# nanofibers show an improved catalytic performance and good
# stability compared to pure La 2O3nanofibers. Firstly, TEM,
# XRD and theoretical studies confirmed that the lattice struc-
# ture of La 2O3can be indeed tailored by Sr insertion. Pure
# La2O3nanofibers used were 20 –30 nm in diameter and several
# micrometers in length with smooth surfaces (Fig. 2a). 8.6 wt%
# Sr–La2O3nanofibers used herein with a rough surface were
# 40–50 nm in diameter and hundreds of nanometers in length
# (Fig. 2b and 3a). The corresponding EDS spectra shown in the
# inset of Fig. 2b were direct evidence of the existence of Sr inhybrid nanofibers. The homogeneous distribution of Sr in
# hybrid nanofibers is presented in the elemental maps
# (Fig. 3d), which clearly revealed the existence and distributionof Sr, La and O elements in hybrid nanofibers, wherein
# diﬀerent colors represent di ﬀerent elements (Fig. 3b –d).
# Unlike the conventional Sr doped La
# 2O3spherical catalyst,
# where Sr easily gets leaked from the doped catalyst under high
# temperature conditions, hybrid Sr –La2O3catalysts are much
# stable during the OCM reaction and the Sr element is homo-geneously distributed in hybrid nanofibers even after reaction,
# as shown in Fig. 3e –h. In particular, TG data of the spent
# Sr–La
# 2O3catalyst indicated that no coke was formed on hybrid
# Sr–La2O3nanofibers, verified by no weight loss measured from
# the spent catalyst (Fig. S4 †). It is of paramount importance to
# achieve the catalytic materials which can resist sintering andcoking at high temperatures.
# Moreover, the introduction of Sr widened the lattice fringes
# of La
# 2O3nanofibers. In Fig. 2c, the crystal lattice fringes ofLa2O3are 0.19, 0.30, 0.31 and 0.33 nm apart, which are in
# agreement with the dvalue of (110), (101), (002) and (100)
# lattice planes of hexagonal La 2O3with growth along the (101)
# direction. For Sr –La2O3nanofibers, the crystal lattice fringes of
# La2O3are 0.20, 0.30, 0.32 and 0.34 nm apart, which corre-
# spond to the dvalue of (110), (101), (002) and (100) lattice
# planes of hexagonal La 2O3. The lattice fringes of (110), (101)
# and (002) lattice planes broaden after introducing Sr, which
# is due to the larger ionic radii of Sr (0.118 nm) than La ions
# (0.1032 nm).
# XRD studies further corroborated the change of the space
# lattice of La 2O3nanofibers viathe insertion of Sr ions into the
# crystal lattice of La 2O3(right panel of Fig. 4). Without Sr inser-
# tion, the lattice parameters of hexagonal La 2O3are 0.3930 nm
# (a), 0.3930 nm ( b) and 0.6109 nm ( c), while in hybrid Sr –La2O3,
# in particular the Sr content is equal to or more than 3.4 wt%,
# Fig. 3 (a) TEM image of fresh Sr –La2O3nano ﬁbers and (b, c, d) the
# corresponding elemental maps for La, O and Sr. (e) TEM image of thespent Sr –La
# 2O3nano ﬁbers and (f, g, h) the corresponding elemental
# maps for La, O and Sr.
# Fig. 1 Catalytic performances of pure La 2O3and hybrid Sr –La2O3nano-
# ﬁbers for OCM reaction: (a) CH 4conversion and (b) C 2yield. The upper
# panel and lower panel of (c) show C 2H6selectivity and C 2H4selectivity. The
# upper panel and lower panel of (d) show CO selectivity and CO 2selectivity.
# Fig. 2 SEM images of (a) pure La 2O3and (b) Sr –La2O3nano ﬁbers, and
# the inset shows the corresponding EDS data. HRTEM images of (c) pure
# La2O3nano ﬁbers and (d) Sr –La2O3nano ﬁbers.Nanoscale Communication
# This journal is © The Royal Society of Chemistry 2015 Nanoscale ,2 0 1 5 , 7, 2260 –2264 | 2261
# Published on 23 December 2014. Downloaded by Durham University Library on 6/24/2024 1:45:13 PM.
# View Article Online
# and basic sites on the surface of La 2O3, and lower the reaction energy of CH 4on the surface of hybrid catalysts, which have been revealed by our studies. We now turn to find the reasons why the hybrid Sr –La2O3 nanofibers show an improved catalytic performance and good stability compared to pure La 2O3nanofibers. Firstly, TEM, XRD and theoretical studies confirmed that the lattice struc- ture of La 2O3can be indeed tailored by Sr insertion. Pure La2O3nanofibers used were 20 –30 nm in diameter and several micrometers in length with smooth surfaces (Fig. 2a). 8.6 wt% Sr–La2O3nanofibers used herein with a rough surface were 40–50 nm in diameter and hundreds of nanometers in length (Fig. 2b and 3a). The corresponding EDS spectra shown in the inset of Fig. 2b were direct evidence of the existence of Sr inhybrid nanofibers. The homogeneous distribution of Sr in hybrid nanofibers is presented in the elemental maps (Fig. 3d), which clearly revealed the existence and distributionof Sr, La and O elements in hybrid nanofibers, wherein diﬀerent colors represent di ﬀerent elements (Fig. 3b –d). Unlike the conventional Sr doped La 2O3spherical catalyst, where Sr easily gets leaked from the doped catalyst under high temperature conditions, hybrid Sr –La2O3catalysts are much stable during the OCM reaction and the Sr element is homo-geneously distributed in hybrid nanofibers even after reaction, as shown in Fig. 3e –h. In particular, TG data of the spent Sr–La 2O3catalyst indicated that no coke was formed on hybrid Sr–La2O3nanofibers, verified by no weight loss measured from the spent catalyst (Fig. S4 †). It is of paramount importance to achieve the catalytic materials which can resist sintering andcoking at high temperatures. Moreover, the introduction of Sr widened the lattice fringes of La 2O3nanofibers. In Fig. 2c, the crystal lattice fringes ofLa2O3are
# 0.19, 0.30, 0.31 and 0.33 nm apart, which are in agreement with the dvalue of (110), (101), (002) and (100) lattice planes of hexagonal La 2O3with growth along the (101) direction. For Sr –La2O3nanofibers, the crystal lattice fringes of La2O3are 0.20, 0.30, 0.32 and 0.34 nm apart, which corre- spond to the dvalue of (110), (101), (002) and (100) lattice planes of hexagonal La 2O3. The lattice fringes of (110), (101) and (002) lattice planes broaden after introducing Sr, which is due to the larger ionic radii of Sr (0.118 nm) than La ions (0.1032 nm). XRD studies further corroborated the change of the space lattice of La 2O3nanofibers viathe insertion of Sr ions into the crystal lattice of La 2O3(right panel of Fig. 4). Without Sr inser- tion, the lattice parameters of hexagonal La 2O3are 0.3930 nm (a), 0.3930 nm ( b) and 0.6109 nm ( c), while in hybrid Sr –La2O3, in particular the Sr content is equal to or more than 3.4 wt%, Fig. 3 (a) TEM image of fresh Sr –La2O3nano ﬁbers and (b, c, d) the corresponding elemental maps for La, O and Sr. (e) TEM image of thespent Sr –La 2O3nano ﬁbers and (f, g, h) the corresponding elemental maps for La, O and Sr. Fig. 1 Catalytic performances of pure La 2O3and hybrid Sr –La2O3nano- ﬁbers for OCM reaction: (a) CH 4conversion and (b) C 2yield. The upper panel and lower panel of (c) show C 2H6selectivity and C 2H4selectivity. The upper panel and lower panel of (d) show CO selectivity and CO 2selectivity. Fig. 2 SEM images of (a) pure La 2O3and (b) Sr –La2O3nano ﬁbers, and the inset shows the corresponding EDS data. HRTEM images of (c) pure La2O3nano ﬁbers and (d) Sr –La2O3nano ﬁbers.Nanoscale Communication This journal is © The Royal Society of Chemistry 2015 Nanoscale ,2 0 1 5 , 7, 2260 –2264 | 2261 Published on 23 December 2014. Downloaded by Durham University Library on 6/24/2024 1:45:13 PM. View Article Onlin
# and the lattice parameters of La 2O3are increased to 0.3934 nm
# (a), 0.3934 nm ( b) and 0.6117 nm ( c), respectively. Interestingly,
# XRD patterns of pure La 2O3and hybrid Sr –La2O3nanofibers
# showed similar di ﬀraction peaks at 2 θ= 26.11°, 29.96°, 46.08°,
# and 52.13°, corresponding to the characteristic di ﬀractions of
# the (100), (101), (110), and (103) planes of La 2O3(JCPDS 05-
# 0602). It is noted that the black rhombus in the XRD of Fig. 4referred to the La
# 2O2CO3phase, which cannot be avoided for
# La2O3to transform into La 2O2CO3in moist air. Red dots in the
# left panel of Fig. 4 stood for the SrCO 3phases, which might be
# generated during the calcination of Sr(NO 3)2–La(OH) 3in the
# air (experimental part in ESI †). Thus these catalysts must be
# pretreated at 800 °C under N 2for 2 h before the OCM test to
# remove these impurities. There is no indication of Sr or related
# oxide phases, suggesting the single component of Sr –La2O3
# themselves rather than the mixture of Sr and La 2O3, except for
# a small amount of SrCO 3and La 2O2CO3. After the reaction,
# the spent Sr –La2O3showed similar XRD di ﬀractions of fresh
# catalysts (Fig. S5 †).
# The change of the La 2O3structure caused viainserting Sr
# was also confirmed by the DFT + Umethod (the periodic plane
# wave DFT implementation in the Vienna ab initio simulation
# program (VASP) code19,20). For the La f orbitals, a value of
# 7.5 eV for the Uparameter for all calculations is presented
# herein as suggested in the literature.21The side and the top
# views of the pure and hybrid Sr –La2O3(101) surfaces, and the
# optimized bond length for the top layer atoms ( e.g.La–O and
# O–Sr) are shown in Fig. 5. The optimized La atom in the
# surface layer of the La 2O3(101) face is coordinated to fourO atoms, with La –O distances of 2.23, 2.23, 2.34 and 2.32 Å
# (Fig. 5a). With Sr introduction, there are four correspondingSr–O, with Sr –O distances of 2.28, 2.28, 2.46 and 2.46 Å
# (Fig. 5b). From the values, the expansion in the structure
# caused by Sr is obvious and such a change in the structureshould result in a di ﬀerence in the activity of hybrid Sr –La
# 2O3
# and pure La 2O3.
# Besides the surface structure of La 2O3tailored by Sr, the
# surface species and surface basic sites on the Sr –La2O3face
# made such a di ﬀerence from that of pure La 2O3. The characteri-
# zation by CO 2-TPD allowed us to demonstrate the nature of
# surface strong basic sites on Sr –La2O3nanofibers (Fig. 6).
# There are three types of basic sites: the weak, medium and
# strong basic site, which are associated with desorption of CO 2
# at the temperatures 100 °C, 300 –600 °C and >600 °C, respect-
# ively. Among the three distinct basic sites, the strong basic
# sites are crucial for the OCM process carried out above 600 °C.The addition of Sr, influencing sharply the strength and quan-
# tity of the base of La
# 2O3, resulted in the creation of more
# strong basic sites compared with intermediate basic sites. Forpure La
# 2O3,m o s tC O 2was desorbed at 300 –600 °C. For 0.8 wt%
# Sr–La2O3, part of CO 2was desorbed at >600 °C, and most
# CO2was desorbed at 300 –600 °C. When the Sr content
# exceeded 3.4 wt% within hybrids, almost all of CO 2was des-
# orbed at 700 –800 °C. It suggests that the surfaces of La 2O3and
# 0.8 wt% Sr –La2O3are dominated by medium basic sites,
# whereas the surface of Sr –La2O3with the Sr content above
# 3.4 wt% is dominated by strong basic sites. The distinct di ﬀer-
# ence of basic sites on the surfaces is one of the reasons for theimproved catalysis of hybrid Sr –La
# 2O3in OCM reaction.
# The roles played by surface oxygen species are, in addition
# to surface basic sites, investigated by XPS analyses. The O 1sspectra of samples can be deconvoluted into four peaks corres-
# ponding to four di ﬀerent oxygen species: superoxide O
# 2−, carbo-
# nate CO 32−, peroxide ions O−, and lattice oxygen O2−, shown
# in Table 1. The electron deficient species such as O 2−and O−
# on the surface of catalysts, as is well-known, are e ﬀective for
# the C 2selectivity, while the lattice oxygen O2−is responsible
# Fig. 4 XRD patterns of La 2O3and Sr –La2O3nano ﬁbers (left panel) and
# lattice parameters ( a,band c)o fL a 2O3and Sr –La2O3nano ﬁbers (right
# panel).
# Fig. 5 The side and top views of (a) pure La 2O3(101) surfaces and (b)
# hybrid Sr –La2O3(101) surfaces.
# Fig. 6 CO 2-TPD pro ﬁles of pure La 2O3and hybrid Sr –La2O3nano ﬁbers.Communication Nanoscale
# 2262 |Nanoscale ,2 0 1 5 , 7, 2260 –2264 This journal is © The Royal Society of Chemistry 2015
# Published on 23 December 2014. Downloaded by Durham University Library on 6/24/2024 1:45:13 PM.
# View Article Online
# and the lattice parameters of La 2O3are increased to 0.3934 nm (a), 0.3934 nm ( b) and 0.6117 nm ( c), respectively. Interestingly, XRD patterns of pure La 2O3and hybrid Sr –La2O3nanofibers showed similar di ﬀraction peaks at 2 θ= 26.11°, 29.96°, 46.08°, and 52.13°, corresponding to the characteristic di ﬀractions of the (100), (101), (110), and (103) planes of La 2O3(JCPDS 05- 0602). It is noted that the black rhombus in the XRD of Fig. 4referred to the La 2O2CO3phase, which cannot be avoided for La2O3to transform into La 2O2CO3in moist air. Red dots in the left panel of Fig. 4 stood for the SrCO 3phases, which might be generated during the calcination of Sr(NO 3)2–La(OH) 3in the air (experimental part in ESI †). Thus these catalysts must be pretreated at 800 °C under N 2for 2 h before the OCM test to remove these impurities. There is no indication of Sr or related oxide phases, suggesting the single component of Sr –La2O3 themselves rather than the mixture of Sr and La 2O3, except for a small amount of SrCO 3and La 2O2CO3. After the reaction, the spent Sr –La2O3showed similar XRD di ﬀractions of fresh catalysts (Fig. S5 †). The change of the La 2O3structure caused viainserting Sr was also confirmed by the DFT + Umethod (the periodic plane wave DFT implementation in the Vienna ab initio simulation program (VASP) code19,20). For the La f orbitals, a value of 7.5 eV for the Uparameter for all calculations is presented herein as suggested in the literature.21The side and the top views of the pure and hybrid Sr –La2O3(101) surfaces, and the optimized bond length for the top layer atoms ( e.g.La–O and O–Sr) are shown in Fig. 5. The optimized La atom in the surface layer of the La 2O3(101) face is coordinated to fourO atoms, with La –O distances of 2.23, 2.23, 2.34 and 2.32 Å (Fig. 5a). With Sr introduction, there are four correspondingSr–O, with Sr –O distances of 2.28, 2.28, 2.46 and 2.46 Å (Fig. 5b). From the values, the expansion in the structure caused by Sr is obvious and such a change in the structureshould result in a di ﬀerence in the activity of hybrid Sr –La 2O3 and pure La 2O3. Besides the surface structure of La 2O3tailored by Sr, the surface species and surface basic sites on the Sr –La2O3face made such a di ﬀerence from that of pure La 2O
# 3. The characteri- zation by CO 2-TPD allowed us to demonstrate the nature of surface strong basic sites on Sr –La2O3nanofibers (Fig. 6). There are three types of basic sites: the weak, medium and strong basic site, which are associated with desorption of CO 2 at the temperatures 100 °C, 300 –600 °C and >600 °C, respect- ively. Among the three distinct basic sites, the strong basic sites are crucial for the OCM process carried out above 600 °C.The addition of Sr, influencing sharply the strength and quan- tity of the base of La 2O3, resulted in the creation of more strong basic sites compared with intermediate basic sites. Forpure La 2O3,m o s tC O 2was desorbed at 300 –600 °C. For 0.8 wt% Sr–La2O3, part of CO 2was desorbed at >600 °C, and most CO2was desorbed at 300 –600 °C. When the Sr content exceeded 3.4 wt% within hybrids, almost all of CO 2was des- orbed at 700 –800 °C. It suggests that the surfaces of La 2O3and 0.8 wt% Sr –La2O3are dominated by medium basic sites, whereas the surface of Sr –La2O3with the Sr content above 3.4 wt% is dominated by strong basic sites. The distinct di ﬀer- ence of basic sites on the surfaces is one of the reasons for theimproved catalysis of hybrid Sr –La 2O3in OCM reaction. The roles played by surface oxygen species are, in addition to surface basic sites, investigated by XPS analyses. The O 1sspectra of samples can be deconvoluted into four peaks corres- ponding to four di ﬀerent oxygen species: superoxide O 2−, carbo- nate CO 32−, peroxide ions O−, and lattice oxygen O2−, shown in Table 1. The electron deficient species such as O 2−and O− on the surface of catalysts, as is well-known, are e ﬀective for the C 2selectivity, while the lattice oxygen O2−is responsible Fig. 4 XRD patterns of La 2O3and Sr –La2O3nano ﬁbers (left panel) and lattice parameters ( a,band c)o fL a 2O3and Sr –La2O3nano ﬁbers (right panel). Fig. 5 The side and top views of (a) pure La 2O3(101) surfaces and (b) hybrid Sr –La2O3(101) surfaces. Fig. 6 CO 2-TPD pro ﬁles of pure La 2O3and hybrid Sr –La2O3nano ﬁbers.Communication Nanoscale 2262 |Nanoscale ,2 0 1 5 , 7, 2260 –2264 This journal is © The Royal Society of Chemistry 2015 Published on 23 December 2014. Downloaded by Durham University Library on 6/24/2024 1:45:13 PM. View Article Online
# for complete oxidation to form CO and CO 2.18,22The ratio of
# the peak intensities of the electron deficient species to latticeoxygen, (O
# 2−+O−)/O2−, can be calculated using the 80% Gaus-
# sian –20% Lorentzian peak shape (Fig. S6 †). From the ratio of
# (O−+O 2−)t oO2−shown in Table 1, 8.6 wt% Sr –La2O3nano-
# fibers have the highest ratio (7.5) and achieved the highest C 2
# selectivity among the hybrid catalysts, which is in accordancewith the literature.
# 18,22
# Fig. 7 (curve a) shows the typical La 3d 5/2of pure La 2O3and
# 8.6 wt% Sr –La2O3nanofibers. After the introduction of Sr, the
# binding energy peak located at 834.3 eV shifted to a lowerbinding energy (833.1 eV), and the energy peak at 837.4 eV
# shifted to a higher binding energy (837.5 eV), revealing that
# the electronic properties of La were changed by Sr insertion.Fig. 7b shows that the Sr 3d spectra could be divided into two
# peaks at the binding energies of 132.1 eV and 133.9 eV, which
# correspond to SrO and SrCO
# 3,23suggesting that Sr occurred on
# the surface of Sr –La2O3in the form of SrO and SrCO 3.
# The comparison of the structure and energetics of the
# associative and dissociative adsorption of CH 4on pure and
# hybrid Sr –La2O3could be made through the DFT study, since
# the reaction pathway of CH 4on the two catalysts is di ﬃcult to
# trace. The optimized structures for the CH 4,C H 3, H and co-
# adsorbed CH 3+ H on Sr –La2O3(101) surfaces are shown in
# Fig. 8, and distances for H –O and C –O are listed in Table 2. In
# Fig. 8, CH 3and H are preferable to be adsorbed at the three
# bonded oxygen atoms near the Sr atom. The corresponding
# optimized structures for the CH 4,C H 3, H and co-adsorbed
# CH 3+ H on pure La 2O3(101) surfaces can be obtained from
# our former work.18The adsorption energies for all the specieson the pure La 2O3surface are all lower than those of the Sr –
# La2O3surface ( −0.11 vs.−0.12 eV for CH 4,−2.34 vs.−3.54 eV
# for CH 3, and −3.40 vs.−4.67 eV for H). The interatomic dis-
# tances between O and H, and O and C on the Sr –La2O3(101)
# surfaces are all shorter than the pure La 2O3surface (2.23 vs.
# 2.33 Å for CH 4, 0.96 vs.0.97 Å for H, and 1.39 vs.1.40 Å for
# CH 3). The same trends are observed in the CH 3+ H co-adsorp-
# tion, with adsorption energies of −4.54 eV and −6.97 eV,
# respectively. Thus, the corresponding reaction energies of CH 4
# activation on (101) of La 2O3and Sr –La2O3are 0.30 and −2.13
# eV, respectively. According to the Brønsted –Evans –Polanyi
# relationship, such a significant di ﬀerence (2.43 eV) in reaction
# energy suggests that methane activation is preferred over the
# (101) surface of Sr –La2O3, even when taking the actual reaction
# conditions into account.
# Conclusions
# In summary, hybrid Sr –La2O3nanofibers enhanced signifi-
# cantly conversion of CH 4and the selectivity of C 2hydrocar-
# bons. In particular, for the 8.6 wt% Sr –La2O3hybrid catalyst,
# the initial ignition temperature of methane was about 500 °C,and methane conversion and C
# 2selectivity were up to ∼35%
# and 47% at 500 °C, respectively. The synergistic e ﬀects of
# material properties of individual Sr and La 2O3optimized inde-
# pendently, i.e.the lattice structure and electronic properties of
# La2O3are tailored by Sr, surface basic sites of La 2O3areTable 1 Curve- ﬁtting results from XPS data
# CatalystsO 1s binding energies (eV)
# (O−+O 2−)/O2−O2−O−CO32−O2−
# La2O3 529.1 531.5 532.7 534.6 5.1
# 0.8 wt% Sr –La2O3 529.1 531.0 532.1 533.6 3.4
# 3.4 wt% Sr –La2O3 528.7 531.1 531.9 534.0 4.3
# 6.0 wt% Sr –La2O3 528.7 531.1 532.0 533.9 4.6
# 8.6 wt% Sr –La2O3 529.1 531.6 533.0 534.6 7.5
# 12.1 wt% Sr –La2O3528.9 531.1 532.1 533.4 5.1
# Fig. 7 (a) XPS La 3d 5/2spectra of La 2O3and 8.6 wt% Sr –La2O3nano ﬁ-
# bers and (b) Sr 3d XPS spectra of 8.6 wt% Sr –La2O3.
# Fig. 8 The optimized structures for the CH 4,C H 3, H and co-adsorbed
# CH 3+ H on Sr –La2O3(101) surfaces.
# Table 2 Adsorption energies, structure parameters of CH 4,C H 3, H and
# co-adsorbed CH 3+ H on pure La 2O3(101) surfaces and Sr –La2O3(101)
# surfaces
# Adsorbates Surface Eads/eV dO–H(Å) dC–H(Å)
# CH 4 La2O3(101) −0.11 2.33
# Sr–La2O3(101) −0.12 2.23
# CH 3 La2O3(101) −2.34 1.40
# Sr–La2O3(101) −3.54 1.39
# HL a 2O3(101) −3.47 0.97
# Sr–La2O3(101) −4.67 0.96
# CH 3+H L a 2O3(101) −4.54 0.98 1.41
# Sr–La2O3(101) −6.97 0.97 1.39Nanoscale Communication
# This journal is © The Royal Society of Chemistry 2015 Nanoscale ,2 0 1 5 , 7, 2260 –2264 | 2263
# Published on 23 December 2014. Downloaded by Durham University Library on 6/24/2024 1:45:13 PM.
# View Article Online
# for complete oxidation to form CO and CO 2.18,22The ratio of the peak intensities of the electron deficient species to latticeoxygen, (O 2−+O−)/O2−, can be calculated using the 80% Gaus- sian –20% Lorentzian peak shape (Fig. S6 †). From the ratio of (O−+O 2−)t oO2−shown in Table 1, 8.6 wt% Sr –La2O3nano- fibers have the highest ratio (7.5) and achieved the highest C 2 selectivity among the hybrid catalysts, which is in accordancewith the literature. 18,22 Fig. 7 (curve a) shows the typical La 3d 5/2of pure La 2O3and 8.6 wt% Sr –La2O3nanofibers. After the introduction of Sr, the binding energy peak located at 834.3 eV shifted to a lowerbinding energy (833.1 eV), and the energy peak at 837.4 eV shifted to a higher binding energy (837.5 eV), revealing that the electronic properties of La were changed by Sr insertion.Fig. 7b shows that the Sr 3d spectra could be divided into two peaks at the binding energies of 132.1 eV and 133.9 eV, which correspond to SrO and SrCO 3,23suggesting that Sr occurred on the surface of Sr –La2O3in the form of SrO and SrCO 3. The comparison of the structure and energetics of the associative and dissociative adsorption of CH 4on pure and hybrid Sr –La2O3could be made through the DFT study, since the reaction pathway of CH 4on the two catalysts is di ﬃcult to trace. The optimized structures for the CH 4,C H 3, H and co- adsorbed CH 3+ H on Sr –La2O3(101) surfaces are shown in Fig. 8, and distances for H –O and C –O are listed in Table 2. In Fig. 8, CH 3and H are preferable to be adsorbed at the three bonded oxygen atoms near the Sr atom. The corresponding optimized structures for the CH 4,C H 3, H and co-adsorbed CH 3+ H on pure La 2O3(101) surfaces can be obtained from our former work.18The adsorption energies for all the specieson the pure La 2O3surface are all lower than those of the Sr – La2O3surface ( −0.11 vs.−0.12 eV for CH 4,−2.34 vs.−3.54 eV for CH 3, and −3.40 vs.−4.67 eV for H). The interatomic dis- tances between O and H, and O and C on the Sr –La2O3(101) surfaces are all shorter than the pure La 2O3surface (2.23 vs. 2.33 Å for CH 4, 0.96 vs.0.97 Å for H, and 1.39 vs.1.40 Å for CH 3). The same trends are observed in the CH 3+ H co-adsorp- tion, with adsorption ene
# rgies of −4.54 eV and −6.97 eV, respectively. Thus, the corresponding reaction energies of CH 4 activation on (101) of La 2O3and Sr –La2O3are 0.30 and −2.13 eV, respectively. According to the Brønsted –Evans –Polanyi relationship, such a significant di ﬀerence (2.43 eV) in reaction energy suggests that methane activation is preferred over the (101) surface of Sr –La2O3, even when taking the actual reaction conditions into account. Conclusions In summary, hybrid Sr –La2O3nanofibers enhanced signifi- cantly conversion of CH 4and the selectivity of C 2hydrocar- bons. In particular, for the 8.6 wt% Sr –La2O3hybrid catalyst, the initial ignition temperature of methane was about 500 °C,and methane conversion and C 2selectivity were up to ∼35% and 47% at 500 °C, respectively. The synergistic e ﬀects of material properties of individual Sr and La 2O3optimized inde- pendently, i.e.the lattice structure and electronic properties of La2O3are tailored by Sr, surface basic sites of La 2O3areTable 1 Curve- ﬁtting results from XPS data CatalystsO 1s binding energies (eV) (O−+O 2−)/O2−O2−O−CO32−O2− La2O3 529.1 531.5 532.7 534.6 5.1 0.8 wt% Sr –La2O3 529.1 531.0 532.1 533.6 3.4 3.4 wt% Sr –La2O3 528.7 531.1 531.9 534.0 4.3 6.0 wt% Sr –La2O3 528.7 531.1 532.0 533.9 4.6 8.6 wt% Sr –La2O3 529.1 531.6 533.0 534.6 7.5 12.1 wt% Sr –La2O3528.9 531.1 532.1 533.4 5.1 Fig. 7 (a) XPS La 3d 5/2spectra of La 2O3and 8.6 wt% Sr –La2O3nano ﬁ- bers and (b) Sr 3d XPS spectra of 8.6 wt% Sr –La2O3. Fig. 8 The optimized structures for the CH 4,C H 3, H and co-adsorbed CH 3+ H on Sr –La2O3(101) surfaces. Table 2 Adsorption energies, structure parameters of CH 4,C H 3, H and co-adsorbed CH 3+ H on pure La 2O3(101) surfaces and Sr –La2O3(101) surfaces Adsorbates Surface Eads/eV dO–H(Å) dC–H(Å) CH 4 La2O3(101) −0.11 2.33 Sr–La2O3(101) −0.12 2.23 CH 3 La2O3(101) −2.34 1.40 Sr–La2O3(101) −3.54 1.39 HL a 2O3(101) −3.47 0.97 Sr–La2O3(101) −4.67 0.96 CH 3+H L a 2O3(101) −4.54 0.98 1.41 Sr–La2O3(101) −6.97 0.97 1.39Nanoscale Communication This journal is © The Royal Society of Chemistry 2015 Nanoscale ,2 0 1 5 , 7, 2260 –2264 | 2263 Published on 23 December 2014. Downloaded by Durham University Library on 6/24/2024 1:45:13 PM. View Article Onlin
# strengthened by Sr, oxygen species on the surface of La 2O3are
# modified by Sr, and methane activation is preferred over the
# Sr–La2O3surface, are believed to be primarily responsible for
# the improved activity and selectivity over Sr –La2O3nanofibers.
# In particular, Sr –La2O3nanofibers have the ability to resist sin-
# tering and further avoid the loss of Sr, as well as there being nocoke formed on the surface of Sr –La
# 2O3catalysts during the high
# temperature reaction. As we have seen, the Sr –La2O3nanocata-
# lysts may open an avenue for a new type of hybrid catalyst withhigh activity and selectivity for oxidative coupling of methane
# carried out at high temperatures, and are promising in a way
# that they will provide new opportunities for studying thenature of hybrid catalysts for high temperature reaction.
# Acknowledgements
# The work was supported by the National Natural Science Foun-dation (21273151, 21403277), the Shanghai Pujiang Program
# (13PJ1407700), and the Shell Global Solutions International
# B. V. and Hundred Talent Program of CAS. We thank Dr CarlMesters and Dr Alexander van der Made from Shell for helpful
# discussions.
# Notes and references
# 1 A. Azetsu, H. Koga, A. Isogai and T. Kitaoka, Catalysts ,
# 2011, 1,8 3–96.
# 2 F. Alosfur, M. H. H. Jumali, S. Radiman, N. J. Ridha,
# M. A. Yarmo and A. A. Umar, Int. J. Electrochem. Sci. , 2013,
# 8, 2977 –2982.
# 3 Y. Lu, Y. Jiang, X. Gao, X. Wang and W. Chen, J. Am. Chem.
# Soc., 2014, 136, 11687 –11697.
# 4 L. L. Chng, N. Erathodiyil and J. Y. Ying, Acc. Chem. Res. ,
# 2013, 46, 1825 –1837.
# 5 M. N. Luwang, S. Chandra, D. Bahadur and K. Srivastava,
# J. Mater. Chem. , 2012, 22, 3395 –3403.
# 6 R. Ferrando, G. Rossi, F. Nita, G. Barcaro and A. Fortunelli,
# ACS Nano , 2008, 2, 1849 –1856.7 J. Guo, H. Li, H. He, D. Chu and R. Chen, J. Phys. Chem. C ,
# 2011, 115, 8494 –8502.
# 8 S. Chen, R. Si, E. Taylor, J. Janzen and J. Chen, J. Phys.
# Chem. C , 2012, 116, 12969 –12976.
# 9 S. Liu, S.-Q. Bai, Y. Zheng, K. W. Shah and M.-Y. Han,
# ChemCatChem , 2012, 4, 1462 –1484.
# 10 K. Maeda, K. Sekizawa and O. I shitani, Chem. Commun. ,
# 2013, 49, 10127 –10129.
# 11 M. Casavola, V. Grillo, E. Carlino, C. Giannini, F. Gozzo,
# E. Fernandez Pinel, M. Angel Garcia, L. Manna,
# R. Cingolani and P. Davide Cozzoli, Nano Lett. , 2007, 7,
# 1386 –1395.
# 12 S. Arndt, G. Laugel, S. Levchenko, R. Horn, M. Baerns,
# M. Sche ﬄer, R. Schloegl and R. Schomaecker, Catal. Rev. ,
# 2011, 53, 424 –514.
# 13 T. Ito, J. X. Wang, C. H. Lin and J. H. Lunsford, J. Am.
# Chem. Soc. , 1985, 107, 5062 –5068.
# 14 J. E. France, A. Shamsi and M. Q. Ahsan, Energy Fuels ,
# 1988, 2, 235 –236.
# 15 M. T. Xu and J. H. Lunsford, Catal. Lett. , 1991, 11, 295 –
# 300.
# 16 J. H. Lunsford, Angew. Chem., Int. Ed. Engl. , 1995, 34, 970 –
# 980.
# 17 J. L. Dubois and C. J. Cameron, Appl. Catal. , 1990, 67,
# 49–71.
# 18 P. Huang, Y. Zhao, J. Zhang, Y. Zhu and Y. Sun, Nanoscale ,
# 2013, 5, 10844 –10848.
# 19 G. Kresse and J. Furthmuller, Phys. Rev. B: Condens. Matter ,
# 1996, 54, 11169 –11186.
# 20 G. Kresse and J. Hafner, Phys. Rev. B: Condens. Matter , 1994,
# 49, 14251 –14269.
# 21 B. Li and H. Metiu, J. Phys. Chem. C , 2010, 114, 12234 –
# 12244.
# 22 W. P. Ding, W. P. Ding, Y. Chen and X. C. Fu, Catal. Lett. ,
# 1994, 23,6 9–78.
# 23 M. V. Bukhtiyarova, A. S. Ivanova, L. M. Plyasova,
# G. S. Litvak, V. A. Rogov, V. V. Kaichev, E. M. Slavinskaya,
# P. A. Kuznetsov and I. A. Polukhina, Appl. Catal., A , 2009,
# 357, 193 –205.Communication Nanoscale
# 2264 |Nanoscale ,2 0 1 5 , 7, 2260 –2264 This journal is © The Royal Society of Chemistry 2015
# Published on 23 December 2014. Downloaded by Durham University Library on 6/24/2024 1:45:13 PM.
# View Article Online
# strengthened by Sr, oxygen species on the surface of La 2O3are modified by Sr, and methane activation is preferred over the Sr–La2O3surface, are believed to be primarily responsible for the improved activity and selectivity over Sr –La2O3nanofibers. In particular, Sr –La2O3nanofibers have the ability to resist sin- tering and further avoid the loss of Sr, as well as there being nocoke formed on the surface of Sr –La 2O3catalysts during the high temperature reaction. As we have seen, the Sr –La2O3nanocata- lysts may open an avenue for a new type of hybrid catalyst withhigh activity and selectivity for oxidative coupling of methane carried out at high temperatures, and are promising in a way that they will provide new opportunities for studying thenature of hybrid catalysts for high temperature reaction. Acknowledgements The work was supported by the National Natural Science Foun-dation (21273151, 21403277), the Shanghai Pujiang Program (13PJ1407700), and the Shell Global Solutions International B. V. and Hundred Talent Program of CAS. We thank Dr CarlMesters and Dr Alexander van der Made from Shell for helpful discussions. Notes and references 1 A. Azetsu, H. Koga, A. Isogai and T. Kitaoka, Catalysts , 2011, 1,8 3–96. 2 F. Alosfur, M. H. H. Jumali, S. Radiman, N. J. Ridha, M. A. Yarmo and A. A. Umar, Int. J. Electrochem. Sci. , 2013, 8, 2977 –2982. 3 Y. Lu, Y. Jiang, X. Gao, X. Wang and W. Chen, J. Am. Chem. Soc., 2014, 136, 11687 –11697. 4 L. L. Chng, N. Erathodiyil and J. Y. Ying, Acc. Chem. Res. , 2013, 46, 1825 –1837. 5 M. N. Luwang, S. Chandra, D. Bahadur and K. Srivastava, J. Mater. Chem. , 2012, 22, 3395 –3403. 6 R. Ferrando, G. Rossi, F. Nita, G. Barcaro and A. Fortunelli, ACS Nano , 2008, 2, 1849 –1856.7 J. Guo, H. Li, H. He, D. Chu and R. Chen, J. Phys. Chem. C , 2011, 115
# , 8494 –8502. 8 S. Chen, R. Si, E. Taylor, J. Janzen and J. Chen, J. Phys. Chem. C , 2012, 116, 12969 –12976. 9 S. Liu, S.-Q. Bai, Y. Zheng, K. W. Shah and M.-Y. Han, ChemCatChem , 2012, 4, 1462 –1484. 10 K. Maeda, K. Sekizawa and O. I shitani, Chem. Commun. , 2013, 49, 10127 –10129. 11 M. Casavola, V. Grillo, E. Carlino, C. Giannini, F. Gozzo, E. Fernandez Pinel, M. Angel Garcia, L. Manna, R. Cingolani and P. Davide Cozzoli, Nano Lett. , 2007, 7, 1386 –1395. 12 S. Arndt, G. Laugel, S. Levchenko, R. Horn, M. Baerns, M. Sche ﬄer, R. Schloegl and R. Schomaecker, Catal. Rev. , 2011, 53, 424 –514. 13 T. Ito, J. X. Wang, C. H. Lin and J. H. Lunsford, J. Am. Chem. Soc. , 1985, 107, 5062 –5068. 14 J. E. France, A. Shamsi and M. Q. Ahsan, Energy Fuels , 1988, 2, 235 –236. 15 M. T. Xu and J. H. Lunsford, Catal. Lett. , 1991, 11, 295 – 300. 16 J. H. Lunsford, Angew. Chem., Int. Ed. Engl. , 1995, 34, 970 – 980. 17 J. L. Dubois and C. J. Cameron, Appl. Catal. , 1990, 67, 49–71. 18 P. Huang, Y. Zhao, J. Zhang, Y. Zhu and Y. Sun, Nanoscale , 2013, 5, 10844 –10848. 19 G. Kresse and J. Furthmuller, Phys. Rev. B: Condens. Matter , 1996, 54, 11169 –11186. 20 G. Kresse and J. Hafner, Phys. Rev. B: Condens. Matter , 1994, 49, 14251 –14269. 21 B. Li and H. Metiu, J. Phys. Chem. C , 2010, 114, 12234 – 12244. 22 W. P. Ding, W. P. Ding, Y. Chen and X. C. Fu, Catal. Lett. , 1994, 23,6 9–78. 23 M. V. Bukhtiyarova, A. S. Ivanova, L. M. Plyasova, G. S. Litvak, V. A. Rogov, V. V. Kaichev, E. M. Slavinskaya, P. A. Kuznetsov and I. A. Polukhina, Appl. Catal., A , 2009, 357, 193 –205.Communication Nanoscale 2264 |Nanoscale ,2 0 1 5 , 7, 2260 –2264 This journal is © The Royal Society of Chemistry 2015 Published on 23 December 2014. Downloaded by Durham University Library on 6/24/2024 1:45:13 PM. View Article Onlin
# Supporting  Information
# Monodisperse  Sr-La 2O3 hybrid nanofibers for oxidative
# coupling of methane to synthesize C 2 hydrocarbons
# Jianjun  Song, a,b Yongnan Sun,a,c Rongbin Ba,a,b Shuangshuang Huang,a,b Yonghui
# Zhao,a Jun Zhang,a Yuhan Suna,* and Yan Zhu a,*
# a CAS Key  Laboratory of Low-Carbon Conversion Science and Engineering, Shanghai Advanced
# Research Institute,  Chinese  Academy of Sciences, Shanghai 201210, China
# b University of Chinese Academy of  Sciences,  Beijing 100049, China
# c Department of Materials Science and Engineering, Shanghai University, Shanghai 200444,
# China
# 1.Experimental
# Preparation of Sr-La 2O3 hybrid  nanofibers
# La2O3 nanofibers  were prepared by precipitation  method. In a typical  process,
# ammonia was added, dropwise, to 0.1 mol/L La(NO 3)3 solution, and stirred for one
# hour to obtain a white gel. After washed  by nanopure  water  for 3 times,  the gel was
# suspended in nanopure  water  and heated at 105 °C for 24 hours. The lanthanum
# hydroxide was isolated  by centrifugation  and suspended in ethanol. After dried at 65
# °C until all ethanol  was removed, the lanthanum  hydroxide nanofibers  were obtained.
# The lanthanum hydroxide nanofibers prepared above were  calcined at 690 °C for 4
# hours to obtain  the La 2O3 nanofibers.
# Sr-La 2O3 nanofibers were synthesized by incipient wetness  impregnation. In a
# typical procedure, different amounts of Sr(NO 3)2 were dissolved  in nanopure  water,
# and then added in a drop-wise  manner  to a certain amount of La(OH) 3 nanofibers
# prepared above until a paste  was obtained. The samples  were then dried at 65 °C and
# calcinated at 800 °C for 4 h to obtain  the Sr-La 2O3 nanofibers. K-La 2O3, Ba-La 2O3,
# and Ca-La 2O3 nanofibers  were prepared  by similar method with Sr-La 2O3 nanofibers.
# Electronic
# Supplementary
# Material
# (ESI)
# for
# Nanoscale.
# This journal is © The Royal Society of Chemistry 2014
# Supporting Information Monodisperse Sr-La 2O3 hybrid nanofibers for oxidative coupling of methane to synthesize C 2 hydrocarbons Jianjun Song, a,b Yongnan Sun,a,c Rongbin Ba,a,b Shuangshuang Huang,a,b Yonghui Zhao,a Jun Zhang,a Yuhan Suna,* and Yan Zhu a,* a CAS Key Laboratory of Low-Carbon Conversion Science and Engineering, Shanghai Advanced Research Institute, Chinese Academy of Sciences, Shanghai 201210, China b University of Chinese Academy of Sciences, Beijing 100049, China c Department of Materials Science and Engineering, Shanghai University, Shanghai 200444, China 1.Experimental Preparation of Sr-La 2O3 hybrid nanofibers La2O3 nanofibers were prepared by precipitation method. In a typical process, ammonia was added, dropwise, to 0.1 mol/L La(NO 3)3 solution, and stirred for one hour to obtain a white gel. After washed by nanopure water for 3 times, the gel was suspended in nanopure water and heated at 1
# 05 °C for 24 hours. The lanthanum hydroxide was isolated by centrifugation and suspended in ethanol. After dried at 65 °C until all ethanol was removed, the lanthanum hydroxide nanofibers were obtained. The lanthanum hydroxide nanofibers prepared above were calcined at 690 °C for 4 hours to obtain the La 2O3 nanofibers. Sr-La 2O3 nanofibers were synthesized by incipient wetness impregnation. In a typical procedure, different amounts of Sr(NO 3)2 were dissolved in nanopure water, and then added in a drop-wise manner to a certain amount of La(OH) 3 nanofibers prepared above until a paste was obtained. The samples were then dried at 65 °C and calcinated at 800 °C for 4 h to obtain the Sr-La 2O3 nanofibers. K-La 2O3, Ba-La 2O3, and Ca-La 2O3 nanofibers were prepared by similar method with Sr-La 2O3 nanofibers. Electronic Supplementary Material (ESI) for Nanoscale. This journal is © The Royal Society of Chemistry 201
# OCM test
# The catalytic measurements  were  carried  out in a laboratory  quartz fixed bed
# reactor (9 mm inner diameter,  14 mm outer diameter,  50 cm length).  Each catalyst
# was pressed under 30 MPa,  then crushed and sieved to a size range of 40-80 mesh.
# For loading the reactor, 0.2 g of the sieved catalyst was mixed with 0.8 g quartz sand,
# and then placed  in the quartz  reactor  tube between two pieces of quartz wool. Before
# the OCM  reaction, the catalysts  were  pretreated under  N2 (flow  rate: 30 mL/min)  at
# 800 °C for 2 h and then switched  to the reactants  consisting 75 % CH 4 and 25% O2
# (flow rate: 240 mL/min) when the feed temperature  dropped  to 400 °C. A cold trap
# was placed at the outlet of the quartz  tube to separate  any condensed water vapor  from
# the reaction products. The non-condensable  gases (H2, CO, CO 2, CH 4, O2, C2H6 and
# C2H4) were  then dried  by the CaCl 2 column, and analyzed on-line  by a micro  gas
# chromatograph (3000 Micro GC; Inficon) equipped with two thermal conductivity
# detectors (TCD), one Molecular sieve 5A and one Plot U columns. Quantitative
# analyses of  products were  using external  standard method.
# Typically, > 99 % of carbon mass balance  was achieved. CH 4 conversion, C2
# selectivity, C2 yield and the selectivity  of other  carbon  products were calculated on the
# basis of  the following equation:
# 4 4
# 4
# 4
# 24 26
# 2
# 2 24 26
# 2 4 2, ,
# 4
# ,
# 2
# 2100%
# )= 100%)CHin CHout
# CH
# CHin
# CH CH
# C
# CO CO CH CH
# C CH CF FCHConversion XF
# x xCSelectivity Sxx x x
# CYield Y X S 
# 
# 
# 2(        + +2(
#
# Characterization
# The X-ray powder  diffraction (XRD)  of the samples  was carried out on a Rigaku
# Ultima X-ray diffractometer using Cu Kα radiation,  scanning in the range 5-90o, with
# a scan rate of 4o/min.  The morphology and composition of the samples were
# examined by Hitachi S-4800  scanning electron microscope  (SEM)  combined with
# OCM test The catalytic measurements were carried out in a laboratory quartz fixed bed reactor (9 mm inner diameter, 14 mm outer diameter, 50 cm length). Each catalyst was pressed under 30 MPa, then crushed and sieved to a size range of 40-80 mesh. For loading the reactor, 0.2 g of the sieved catalyst was mixed with 0.8 g quartz sand, and then placed in the quartz reactor tube between two pieces of quartz wool. Before the OCM reaction, the catalysts were pretreated under N2 (flow rate: 30 mL/min) at 800 °C for 2 h and then switched to the reactants consisting 75 % CH 4 and 25% O2 (flow rate: 240 mL/min) when the feed temperature dropped to 400 °C. A cold trap was placed at the outlet of the quartz tube to separate any condensed water vapor from the reaction products. The non-condensable gases (H2, CO, CO 2, CH 4, O2, C2H6 and C2H4) were then dried by the CaCl 2 column, and analyzed on-line by a micro ga
# s chromatograph (3000 Micro GC; Inficon) equipped with two thermal conductivity detectors (TCD), one Molecular sieve 5A and one Plot U columns. Quantitative analyses of products were using external standard method. Typically, > 99 % of carbon mass balance was achieved. CH 4 conversion, C2 selectivity, C2 yield and the selectivity of other carbon products were calculated on the basis of the following equation: 4 4 4 4 24 26 2 2 24 26 2 4 2, , 4 , 2 2100% )= 100%)CHin CHout CH CHin CH CH C CO CO CH CH C CH CF FCHConversion XF x xCSelectivity Sxx x x CYield Y X S    2( + +2( Characterization The X-ray powder diffraction (XRD) of the samples was carried out on a Rigaku Ultima X-ray diffractometer using Cu Kα radiation, scanning in the range 5-90o, with a scan rate of 4o/min. The morphology and composition of the samples were examined by Hitachi S-4800 scanning electron microscope (SEM) combined wit
# Bruker quanta 400 Energy  Dispersive  X-ray Fluorescence Spectrometer (EDS).
# Transmission electron microscopy  (TEM) was performed on a FEI Tecnai G2 F20 S-
# TWIN transmission electron microscope  at an operating voltage  of 200 kV, equipped
# with a Gatan Orius CCD camera. X-ray photoelectron spectra (XPS) were recorded
# on a Thermo Fisher Scientiﬁc K-Alpha  X-ray  photoelectron spectrometer.  For all the
# computer ﬁts, the XPS peaks were assumed to have  80% Gaussian plus 20%
# Lorentzian peak shape. CO 2 temperature-programmed desorption measurements were
# performed on Micromeritics AutoChem II 2920 instrument connected to a MKS
# cirrus mass spectrum. The catalyst power (150 mg) was heated a He ﬂow from  60 to
# 800 °C at a heating  rate of 10 °C /min and keep  for 60 min at 800 °C, and then cooled
# to 60 °C. The CO 2 was injected at 60 °C for 60 min. The CO 2 was switched to He for
# 60 min, and the CO 2-TPD results were recorded at a heating rate of 10 °C /min. The
# CO 2 desorbed was measured quantitatively by mass spectrum.  Thermogravimetric
# (TG) experiments were  performed under  30 mL/min Air (20 % O2 + 80 % N2) with a
# heating rate  of 5 oC/min on a Netzsch STA 449 F3 thermoanalyzer.
# Supporting Figures
# 400 500 600 700 800010203040
#  Sr/La2O3 nanoparticles
#  Sr-La2O3 nanofibers
#   CH4 Conversion (%)
# Temperature (oC)400 500 600 700 80005101520
#  Sr/La2O3 nanoparticles
#  Sr-La2O3 nanofibers
#   C2 Yield (%)
# Temperature (oC)
# Figure S1. Comparison of OCM test for Sr-La 2O3 nanofibers  and Sr/La 2O3
# nanoparticles. (The synthesis of La 2O3 nanoparticles  are referred to ref.18)
# Bruker quanta 400 Energy Dispersive X-ray Fluorescence Spectrometer (EDS). Transmission electron microscopy (TEM) was performed on a FEI Tecnai G2 F20 S- TWIN transmission electron microscope at an operating voltage of 200 kV, equipped with a Gatan Orius CCD camera. X-ray photoelectron spectra (XPS) were recorded on a Thermo Fisher Scientiﬁc K-Alpha X-ray photoelectron spectrometer. For all the computer ﬁts, the XPS peaks were assumed to have 80% Gaussian plus 20% Lorentzian peak shape. CO 2 temperature-programmed desorption measurements were performed on Micromeritics AutoChem II 2920 instrument connected to a MKS cirrus mass spectrum. The catalyst power (150 mg) was heated a He ﬂow from 60 to 800 °C at a heating rate of 10 °C /min and keep for 60 min at 800 °C, and t
# hen cooled to 60 °C. The CO 2 was injected at 60 °C for 60 min. The CO 2 was switched to He for 60 min, and the CO 2-TPD results were recorded at a heating rate of 10 °C /min. The CO 2 desorbed was measured quantitatively by mass spectrum. Thermogravimetric (TG) experiments were performed under 30 mL/min Air (20 % O2 + 80 % N2) with a heating rate of 5 oC/min on a Netzsch STA 449 F3 thermoanalyzer. Supporting Figures 400 500 600 700 800010203040 Sr/La2O3 nanoparticles Sr-La2O3 nanofibers CH4 Conversion (%) Temperature (oC)400 500 600 700 80005101520 Sr/La2O3 nanoparticles Sr-La2O3 nanofibers C2 Yield (%) Temperature (oC) Figure S1. Comparison of OCM test for Sr-La 2O3 nanofibers and Sr/La 2O3 nanoparticles. (The synthesis of La 2O3 nanoparticles are referred to ref.18)
# 400 500 600 700 800010203040
#   CH4 Conversion (%)
# Temperature (oC) K-La2O3
#  Ba-La2O3
#  Ca-La2O3
#  Sr-La2O3
# 400 500 600 700 80005101520
#  K-La2O3
#  Ba-La2O3
#  Ca-La2O3
#  Sr-La2O3
#   C2 Yield (%)
# Temperature (oC)
# Figure S2. Comparison of  OCM test for K-La 2O3 (5 wt% K),  Ba-La 2O3 (3.8 wt% Ba),
# Ca-La 2O3 (8.6 wt% Ca) and Sr-La 2O3 (8.6 wt% Sr) nanofibers for OCM reaction.
# 0102030405060708090100020406080100
# 020406080100
# C2 yield (%)  CH4 Conversion (%)
# Time on the stream (h) CH4 conversion
#  C2 yield
# Figure S3. The stability of Sr-La 2O3 for OCM reaction  under  below condition:
# reaction time =100 h, T=650oC, P = 1 atm,  CH 4/O2 =3, GHSV = 72000 ml·g-1·h-1.
# 400 500 600 700 800010203040 CH4 Conversion (%) Temperature (oC) K-La2O3 Ba-La2O3 Ca-La2O3 Sr-La2O3 400 500 600 700 80005101520 K-La2O3 Ba-La2O3 Ca-La2O3 Sr-La2O3 C2 Yield (%) Temperature (oC) Figure S2. Comparison of OCM test for K-La 2O3 (5 wt% K), Ba-La 2O3 (3.8 wt% Ba), Ca-La 2O3 (8.6 wt% Ca) and Sr-La 2O3 (8.6 w
# t% Sr) nanofibers for OCM reaction. 0102030405060708090100020406080100 020406080100 C2 yield (%) CH4 Conversion (%) Time on the stream (h) CH4 conversion C2 yield Figure S3. The stability of Sr-La 2O3 for OCM reaction under below condition: reaction time =100 h, T=650oC, P = 1 atm, CH 4/O2 =3, GHSV = 72000 ml·g-1·h-1
# 100200300400500600700800900020406080100
#   Mass (%)
# Temperature (oC)
# Figure S4. T G pattern  of spent 8.6 wt% Sr-La 2O3 nanofibers under  30 mL/min Air
# (20 % O 2 + 80 % N2).
# 20 30 40 50 60 70 80103110101
# SrCO3
#  Intensity (a.u.)
# 
# 2  (degree)100
# Figure S5. XRD pattern of spent 8.6 wt% Sr-La 2O3 nanofibers
# 100200300400500600700800900020406080100 Mass (%) Temperature (oC) Figure S4. T G pattern of spent 8.6 wt% Sr-La 2O3 nanofibers under 30 mL/min Air (20
# % O 2 + 80 % N2). 20 30 40 50 60 70 80103110101 SrCO3 Intensity (a.u.)  2  (degree)100 Figure S5. XRD pattern of spent 8.6 wt% Sr-La 2O3 nanofiber
# 538 536 534 532 530 528 5264 12
#
# Binding Energy (eV)3La2O3
# 538 536 534 532 530 528 526413
#
# Binding Energy (eV)20.8 wt%
# Sr-La2O3
# 538 536 534 532 530 528 5262
# 13
#
# Binding Energy (eV)43.4 wt%
# Sr-La2O3
# 538 536 534 532 530 528 5262
# 12
#
# Binding Energy (eV)46.0 wt%
# Sr-La2O3
#          538 536 534 532 530 528 526342
#
# Binding Energy (eV)18.6 wt%
# Sr-La2O3
# 538 536 534 532 530 528 52632
# 4
#
# Binding Energy (eV)112.1 wt%
# Sr-La2O3
# Figure S6. O1s binding energy spectra of fresh catalysts.
# 538 536 534 532 530 528 5264 12 Binding Energy (eV)3La2O3 538 536 534 532 530 528 526413 Binding Energy (eV)20.8 wt% Sr-La2O3 538 536 534 532 530 528 5262 13 Binding Energy (eV)43.4 wt% Sr-La2O3 538 536 534 532 530 528 5262 12 Bi
# nding Energy (eV)46.0 wt% Sr-La2O3 538 536 534 532 530 528 526342 Binding Energy (eV)18.6 wt% Sr-La2O3 538 536 534 532 530 528 52632 4 Binding Energy (eV)112.1 wt% Sr-La2O3 Figure S6. O1s binding energy spectra of fresh catalysts
# Initial Data Extraction Complete

# %%
def save_df_to_csv(df, filename):
    df.to_csv(filename, index=False)

def load_df_from_csv(filename):
    df = pd.read_csv(filename)
    df['embedding'] = df['embedding'].apply(ast.literal_eval)

    return df

def add_embedding(df):
    # If the dataframe already has 'embedding' column, return as is
    if 'embedding' in df.columns:
        return df
    # Define a function to get embeddings
    def get_embedding(text):
        response = client.embeddings.create(
            input = text,
            model = "text-embedding-ada-002"
        )
        return response.data[0].embedding
    # Apply the function to the 'content' column
    df['embedding'] = df['content'].apply(get_embedding)
    return df

# %%
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity

def add_similarity(df, given_embedding):
    def calculate_similarity(row_embedding):
        return cosine_similarity([row_embedding], [given_embedding])[0][0]
    df['similarity'] = df['embedding'].apply(calculate_similarity)
    return df

def select_top_neighbors(df):
    df = df.sort_values('similarity', ascending=False)
    top_neighbors = df.head(20)
    return top_neighbors

# %%
def Model_OCM(df):
    max_tokens = 3000
    df.loc[:, 'tokens'] = df['content'].apply(count_tokens)
    summarized = []
    for i, row in df.iterrows():
        content = row['content']
        token_count = row['tokens']
        print(token_count)
        if token_count > max_tokens: # Split the content into chunks of max_tokens
            content_chunks = [' '.join(content.split()[i:i+max_tokens]) for i in range(0,
            token_count, max_tokens)]
        else:
            content_chunks = [content]
        for chunk in content_chunks:
            prompt = f"Context: {chunk} Given tubulation prompt"
            response = client.chat.completions.create(model="gpt-4o", messages=[{"role": "user", "content": prompt}])
            answer = response.choices[0].message.content
            summarized.append(answer)
    df.loc[:, 'summarized'] = pd.Series(summarized, index=df.index)
    return df

# %%
def tabulate_ocm_conditions(df):
    columns = [
        'catalyst name', 'catalyst mass', 'GHSV / mL gcat-1 hr-1', 'Flow / mL min-1', 
        'Temperature / degree C', '% CH4', '% CH4 conversion', '% C2 selectivity'
    ]
    
    # Initialize an empty dataframe with the desired columns
    result_df = pd.DataFrame(columns=columns)
    
    for index, row in df.iterrows():
        summarized = row['summarized']
        
        # Check if the "|" symbol is present in the text string
        if "|" in summarized:
            # Split the text string into lines and ignore the header
            lines = summarized.strip().split("\n")[2:]  # Assuming the first two lines are headers
            
            for line in lines:
                data = [x.strip() for x in line.split("|")]
                if len(data) == len(columns):
                    # Convert the data into a DataFrame and concatenate it with the result DataFrame
                    temp_df = pd.DataFrame([data], columns=columns)
                    result_df = pd.concat([result_df, temp_df], ignore_index=True)
    
    return result_df

# %%
import pandas as pd
# Sample data as it might appear in the DataFrame
sample_data = {
    'summarized': [
        """
        catalyst name | catalyst mass | GHSV / mL gcat-1 hr-1 | Flow / mL min-1 | Temperature / degree C | % CH4 | % CH4 conversion | % C2 selectivity
        -------------|---------------|-----------------------|-----------------|-----------------------|-------|------------------|-----------------
        Sr-La2O3     | 0.2 g         | 72000                 | 240             | 500                   | 75    | 35               | 47
        Mg-CaO       | 0.3 g         | 65000                 | 220             | 450                   | 70    | 30               | 50
        """
    ]
}

# Create a DataFrame
sample_df = pd.DataFrame(sample_data)

# Test the function
result = tabulate_ocm_conditions(sample_df)

# Print the result to see if it worked correctly
print(result)
# Out:
#   catalyst name catalyst mass GHSV / mL gcat-1 hr-1 Flow / mL min-1  \
# 0      Sr-La2O3         0.2 g                 72000             240
# 1        Mg-CaO         0.3 g                 65000             220
#
#   Temperature / degree C % CH4 % CH4 conversion % C2 selectivity
# 0                    500    75               35               47
# 1                    450    70               30               50

# %%
file_names = ['./Document/c4nr06660j.pdf', './Document/c4nr06660j1.pdf']
client = OpenAI(api_key = OPENAI_API_KEY, )

df = process_pdf_files(file_names)
print("Initial Data Extraction Complete")
        
df.to_csv('extracted_data.csv', index=False)
print("Data saved to CSV.")
        
# Add embeddings to the DataFrame
df = add_embedding(df)
print("Embeddings added.")
        
# If you are using Model_3, Model_2, or any other function that further processes the data
df = Model_OCM(df)
print("Data processed through Model_3.")
# Out:
# Initial Data Extraction Complete
# Data saved to CSV.
# Embeddings added.
# 130
# 86
# 80
# 92
# 153
# 132
# 133
# 121
# 87
# 82
# 37
# 45
# 37
# 49
# 30
# 35
# 18
# 30
# 9
# 8
# 18
# 23
# Data processed through Model_3.

# %%
print(df)
# Out:
#                      file name  page number  section number  \
# 0    ./Document/c4nr06660j.pdf            1               1
# 1    ./Document/c4nr06660j.pdf            1               2
# 2    ./Document/c4nr06660j.pdf            2               1
# 3    ./Document/c4nr06660j.pdf            2               2
# 4    ./Document/c4nr06660j.pdf            3               1
# 5    ./Document/c4nr06660j.pdf            3               2
# 6    ./Document/c4nr06660j.pdf            4               1
# 7    ./Document/c4nr06660j.pdf            4               2
# 8    ./Document/c4nr06660j.pdf            5               1
# 9    ./Document/c4nr06660j.pdf            5               2
# 10  ./Document/c4nr06660j1.pdf            1               1
# 11  ./Document/c4nr06660j1.pdf            1               2
# 12  ./Document/c4nr06660j1.pdf            2               1
# 13  ./Document/c4nr06660j1.pdf            2               2
# 14  ./Document/c4nr06660j1.pdf            3               1
# 15  ./Document/c4nr06660j1.pdf            3               2
# 16  ./Document/c4nr06660j1.pdf            4               1
# 17  ./Document/c4nr06660j1.pdf            4               2
# 18  ./Document/c4nr06660j1.pdf            5               1
# 19  ./Document/c4nr06660j1.pdf            5               2
# 20  ./Document/c4nr06660j1.pdf            6               1
# 21  ./Document/c4nr06660j1.pdf            6               2
#
#                                               content  tokens  \
# 0   Nanoscale COMMUNICATION Cite this: Nanoscale ,...     130
# 1   hu*a The synergistic e ﬀects from combinations...      86
# 2   and basic sites on the surface of La 2O3, and ...      80
# 3    Firstly, TEM, XRD and theoretical studies con...      92
# 4   and the lattice parameters of La 2O3are increa...     153
# 5   he black rhombus in the XRD of Fig. 4referred ...     132
# 6   for complete oxidation to form CO and CO 2.18,...     133
# 7   e hybrid catalysts, which is in accordancewith...     121
# 8   strengthened by Sr, oxygen species on the surf...      87
# 9   oid the loss of Sr, as well as there being noc...      82
# 10  Supporting Information Monodisperse Sr-La 2O3 ...      37
# 11  a,b Yongnan Sun,a,c Rongbin Ba,a,b Shuangshuan...      45
# 12  OCM test The catalytic measurements were carri...      37
# 13  was pressed under 30 MPa, then crushed and sie...      49
# 14  Bruker quanta 400 Energy Dispersive X-ray Fluo...      30
# 15   a FEI Tecnai G2 F20 S- TWIN transmission elec...      35
# 16  400 500 600 700 800010203040 CH4 Conversion (%...      18
# 17  rature (oC) K-La2O3 Ba-La2O3 Ca-La2O3 Sr-La2O3...      30
# 18                        100200300400500600700800900       9
# 19                        020406080100 Mass (%) Tempe       8
# 20          538 536 534 532 530 528 5264 12 Binding E      18
# 21          nergy (eV)3La2O3 538 536 534 532 530 528       23
#
#                                             embedding  \
# 0   [-0.019589116796851158, 0.019193239510059357, ...
# 1   [-0.004032593686133623, 0.022350935265421867, ...
# 2   [0.011938540264964104, 0.007674306631088257, -...
# 3   [0.014609415084123611, 0.0212161336094141, -0....
# 4   [0.006260937545448542, 0.011178558692336082, 0...
# 5   [0.0012409996706992388, 0.01340178307145834, 0...
# 6   [0.006820357870310545, 0.013393576256930828, -...
# 7   [0.0032126563601195812, -0.003961826208978891,...
# 8   [0.00805845856666565, -0.007214892655611038, -...
# 9   [0.0032201260328292847, -0.0022194834891706705...
# 10  [-0.011205121874809265, 0.020202867686748505, ...
# 11  [0.012847232632339, -0.01186934020370245, 0.00...
# 12  [0.0006227684207260609, 0.006626255810260773, ...
# 13  [-0.0058037894777953625, 0.0031853436958044767...
# 14  [-0.00739859277382493, -0.013839482329785824, ...
# 15  [-0.0027874347288161516, 0.002029463415965438,...
# 16  [0.009430334903299809, -0.02456527203321457, -...
# 17  [0.025969000533223152, 0.0013627363368868828, ...
# 18  [-0.004980774130672216, -0.01755162887275219, ...
# 19  [-0.0040581985376775265, -0.005676562897861004...
# 20  [-0.014913663268089294, -0.006714568939059973,...
# 21  [0.028936848044395447, -0.010993619449436665, ...
#
#                                            summarized
# 0   Monodisperse Sr–La2O3 Hybrid Nanofibers for Ox...
# 1   Given that you need to discuss the improved ca...
# 2   To understand the improved catalytic performan...
# 3   Context: Firstly, TEM, XRD, and theoretical st...
# 4   Thank you for providing the context. It appear...
# 5   Sure! Below is a streamlined and concise expla...
# 6   I'm sorry, but the context you have provided s...
# 7   Given the context, it seems like you're lookin...
# 8   **Given the context regarding Sr–La₂O₃ nanofib...
# 9   Given the tubulation of reaction gases and pro...
# 10  Certainly! Could you please provide more detai...
# 11  Based on the context provided, it seems like y...
# 12  Given the context of an OCM (Oxidative Couplin...
# 13  The prompt provided elucidates a preparation o...
# 14  To provide you with the specific information o...
# 15  The FEI Tecnai G2 F20 S-TWIN transmission elec...
# 16  It appears that you're referring to data or a ...
# 17  It looks like there was an issue with the cont...
# 18  It looks like you've provided a numerical sequ...
# 19  It seems like you have provided some segmented...
# 20  It seems like the context you've provided incl...
# 21  It appears that context involves energy levels...

# %%
df.to_csv('filename.csv', index=False)
